# %%
# Conda env Activation
conda activate vit1

# Make sure you're in the thermal_env virtual environment
source thermal_env/bin/activate

# Check wether it uses the env python
which python

# %%
# Run api.py with nohup, redirect output to a log file, and run in background
nohup python api.py > logs/api_log.out 2>&1 &


# close the terminal with
exit

# %%
# The command above will print a process ID (PID)
# You can use this PID later to stop the process if needed save it
echo $! > api.pid

2098813
